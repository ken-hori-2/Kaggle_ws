# %%
# ライブラリのimport
import pandas as pd
# データの読み込み
data = pd.read_csv('data.tsv', sep='\t')
# idの削除
data = data.drop(columns=['id'])
# 欠損値を含む行の削除
data = data.dropna()

# 説明変数と目的変数の取り出し
y = data['kpl']
X = data[['cylinders','displacement','horsepower','acceleration','model_year','origin']]

# scikit-learnライブラリからtrain_test_split関数をインポート
from sklearn.model_selection import train_test_split

# 学習データと評価データに分割
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=32)

# X_trainとX_testから行数を取り出し、それぞれ変数X_train_line, X_test_lineに代入し、表示
X_train_line = X_train.shape[0]
X_test_line = X_test.shape[0]
print(X_train_line)
print(X_test_line)

# %%
# ライブラリのimport
import pandas as pd
from sklearn.model_selection import train_test_split

# データの読み込み
data = pd.read_csv('data.tsv', sep='\t')

# idの削除
data = data.drop(columns=['id'])

# 欠損値を含む行の削除
data = data.dropna()

# 目的変数と説明変数の準備
X = data[['cylinders','displacement','horsepower','acceleration','model_year','origin']]
y = data['kpl']

# 学習用データと評価用データの分割
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=32)

# sklearnからLinearRegressionのインポート
from sklearn.linear_model import LinearRegression as LR

# モデルの箱を準備
lr = LR()

# モデルを学習
lr.fit(X_train, y_train)

# %% [markdown]
# # Clear!
# 50EXPを獲得
#
# operation-tips
# 今回は、RMSEを使って重回帰モデルの予測精度を評価しました。
# 予測精度はRMSE=3.969048746613913であり、学習データに対しては誤差±4程度で予測ができていることがわかります。
# 今回のケースに限らず、別のモデルやタスクにおいても、学習したモデルに対して、予測結果を求め、正解と予測値の比較を行うことで、モデルの良さを判断することは変わりません。

# %%
# ライブラリのimport
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as LR

# データの読み込み
data = pd.read_csv('data.tsv', sep='\t')

# idの削除
data = data.drop(columns=['id'])

# 欠損値を含む行の削除
data = data.dropna()

# 目的変数と説明変数の準備
X = data[['cylinders','displacement','horsepower','acceleration','model_year','origin']]
y = data['kpl']

# 学習用データと評価用データの分割
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=32)

# モデルの箱を準備
lr = LR()

# モデルを学習
lr.fit(X_train, y_train)

# モデルから予測結果を求める
y_pred_train = lr.predict(X_train)

# sklearnライブラリからMSEモジュールのimport
from sklearn.metrics import mean_squared_error as MSE

# MSEの算出
mse = MSE(y_train, y_pred_train)

# RMSEの算出
rmse_train = np.sqrt(mse)

# RMSEの表示
print(rmse_train)

# %%
# X_testに対する予測値を算出る
y_pred_test = lr.predict(X_test)

# 予測値を表示
print(y_pred_test)

# %%
# ライブラリのimport
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_squared_error as MSE

# データの読み込み
data = pd.read_csv('data.tsv', sep='\t')

# idの削除
data = data.drop(columns=['id'])

# 欠損値を含む行の削除
data = data.dropna()

# 目的変数と説明変数の準備
X = data[['cylinders','displacement','horsepower','acceleration','model_year','origin']]
y = data['kpl']

# 学習用データと評価用データの分割
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=32)

# モデルの箱を準備
lr = LR()

# モデルを学習
lr.fit(X_train, y_train)

# モデルから予測結果を求める
y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

# 学習データのRMSEの算出
mse_train = MSE(y_train, y_pred_train)
rmse_train = np.sqrt(mse_train)

# 評価データのRMSEの算出
mse_test = MSE(y_test,y_pred_test)
rmse_test = np.sqrt(mse_test)

# 学習および評価データに対するRMSEを表示
print(rmse_train)
print(rmse_test)

# %% [markdown]
# # 精度改善
# ダミー変数化+対数化での予測精度
#
#
# Clear!
# 50EXPを獲得
# operation-tips
# 今回は、説明変数の対数化を行った上で、もう一度予測モデルを構築しました。
#
# RMSEは誤差を表す評価関数であり評価値が小さいほど予測精度が高いことを意味しました。
#
# 改善してきたモデルの予測精度を確認すると、RMSEによる評価値が下がっている為、予測精度が改善してきたことが確認できます。
#
# ダミー変数化での予測精度
# 学習データへの予測精度：2.484610511471511
# 評価データへの予測精度：2.539093752472859
# ダミー変数化+対数化での予測精度
# 学習データへの予測精度：2.389312041429009
# 評価データへの予測精度：2.367965832443981
# データの準備から予測モデルの作成及び予測精度までの流れの基礎をクエストを通じて学ぶことができました。
#
# 他の予測モデルを利用した場合も、基本的には同じ流れで予測モデルの構築から評価までを行うことになります。
# 以上でMission4「燃費予測モデルの予測精度改善」は終了となります。お疲れ様でした。
# 今回のクエストでは数値データを予測する回帰問題をテーマに、データの準備から重回帰モデルの作成、そして特徴量加工までを学びました。この分析の流れは基本的には全てのデータ分析において共通する非常に重要なプロセスとなりますので、ぜひ身につけてください。次は本クエストの内容をまとめたConclusion動画がありますので、こちらもご視聴ください。

# %%
#ライブラリのimport
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression as LR
from sklearn.metrics import mean_squared_error as MSE

# データの読み込み
data = pd.read_csv('data.tsv', sep='\t')

# idの削除
data = data.drop(columns=['id'])

# 欠損値を含む行の削除
data = data.dropna() 

# 対数化
data['displacement_log']= np.log(data['displacement'])

# 目的変数及び説明変数を表す変数の準備
y = data['kpl'] # 目的変数
X = data[['cylinders','horsepower','acceleration','model_year','origin','drive_system','displacement_log']] # 説明変数
X = pd.get_dummies(X) # 各説明変数のダミー変数化

# データの分割
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# モデルの箱の準備および学習
lr = LR()
lr.fit(X_train, y_train)

# 予測値の算出
y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)

# MSEの算出
mse_train = MSE(y_pred_train, y_train)
mse_test = MSE(y_pred_test, y_test)

# RMSEの算出
rmse_train = np.sqrt(mse_train)
rmse_test = np.sqrt(mse_test)

# RMSEの表示
print(rmse_train)
print(rmse_test)
